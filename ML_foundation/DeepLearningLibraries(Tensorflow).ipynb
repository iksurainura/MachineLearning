# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
import tensorflow as tf

# %%
# generate a 2D binary classification dataset
X,Y=make_classification(n_samples=500,n_features=2,n_informative=2,n_redundant=0,n_clusters_per_class=1,random_state=42)

# 2. Scale the features
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

#3. Train-test split
x_train,x_test,y_train,y_test=train_test_split(X_scaled,Y,test_size=0.2,random_state=42)

# %%
# 4. Define a simple neural network model in keras 
model=tf.keras.Sequential([
    tf.keras.layers.Dense(20,activation='relu',input_shape=(2,)),
    tf.keras.layers.Dense(1,activation='sigmoid')
])

#5. Compile the model
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

#6. train the model and capture training history
history =model.fit(x_train,y_train,epochs=30,batch_size=16,validation_split=0.2)
# Out:
# Epoch 1/30
# c:\Users\IksuraW\Downloads\New folder\MachineLearning\env\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8469 - loss: 0.5388 - val_accuracy: 0.8500 - val_loss: 0.5404
# Epoch 2/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8625 - loss: 0.5062 - val_accuracy: 0.8500 - val_loss: 0.5114
# Epoch 3/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8562 - loss: 0.4786 - val_accuracy: 0.8625 - val_loss: 0.4831
# Epoch 4/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8594 - loss: 0.4532 - val_accuracy: 0.8625 - val_loss: 0.4593
# Epoch 5/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8625 - loss: 0.4313 - val_accuracy: 0.8750 - val_loss: 0.4361
# Epoch 6/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8594 - loss: 0.4112 - val_accuracy: 0.9000 - val_loss: 0.4161
# Epoch 7/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8531 - loss: 0.3938 - val_accuracy: 0.9000 - val_loss: 0.3978
# Epoch 8/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8531 - loss: 0.3781 - val_accuracy: 0.9125 - val_loss: 0.3811
# Epoch 9/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8531 - loss: 0.3647 - val_accuracy: 0.9125 - val_loss: 0.3678
# Epoch 10/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8562 - loss: 0.3522 - val_accuracy: 0.9125 - val_loss: 0.3538
# Epoch 11/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8594 - loss: 0.3417 - val_accuracy: 0.9000 - val_loss: 0.3416
# Epoch 12/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8656 - loss: 0.3325 - val_accuracy: 0.9000 - val_loss: 0.3322
# Epoch 13/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8625 - loss: 0.3244 - val_accuracy: 0.9000 - val_loss: 0.3229
# Epoch 14/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8625 - loss: 0.3173 - val_accuracy: 0.9000 - val_loss: 0.3156
# Epoch 15/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8625 - loss: 0.3110 - val_accuracy: 0.9000 - val_loss: 0.3094
# Epoch 16/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8625 - loss: 0.3054 - val_accuracy: 0.9000 - val_loss: 0.3021
# Epoch 17/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8656 - loss: 0.3005 - val_accuracy: 0.9000 - val_loss: 0.2968
# Epoch 18/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8656 - loss: 0.2961 - val_accuracy: 0.9000 - val_loss: 0.2923
# Epoch 19/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8687 - loss: 0.2925 - val_accuracy: 0.9000 - val_loss: 0.2873
# Epoch 20/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8656 - loss: 0.2889 - val_accuracy: 0.9000 - val_loss: 0.2830
# Epoch 21/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8656 - loss: 0.2858 - val_accuracy: 0.9000 - val_loss: 0.2800
# Epoch 22/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8687 - loss: 0.2824 - val_accuracy: 0.9000 - val_loss: 0.2752
# Epoch 23/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8719 - loss: 0.2792 - val_accuracy: 0.9000 - val_loss: 0.2721
# Epoch 24/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8750 - loss: 0.2767 - val_accuracy: 0.9000 - val_loss: 0.2705
# Epoch 25/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8750 - loss: 0.2740 - val_accuracy: 0.9000 - val_loss: 0.2664
# Epoch 26/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8687 - loss: 0.2718 - val_accuracy: 0.9000 - val_loss: 0.2621
# Epoch 27/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8750 - loss: 0.2692 - val_accuracy: 0.9000 - val_loss: 0.2615
# Epoch 28/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8750 - loss: 0.2668 - val_accuracy: 0.9000 - val_loss: 0.2587
# Epoch 29/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8687 - loss: 0.2652 - val_accuracy: 0.9000 - val_loss: 0.2571
# Epoch 30/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8719 - loss: 0.2634 - val_accuracy: 0.9000 - val_loss: 0.2532

# %%
#7. plot the dataset

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(X_scaled[:,0],X_scaled[:,1],c=Y ,cmap='bwr',edgecolors='k',alpha=0.7)
plt.title("2D Binary Classification Dataset")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.grid(True)

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'],label='Train Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.title('Model Accuracy vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
